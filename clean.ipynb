# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('./data/processed/processed_temp_data.CSV')
data.head(5)
# Out:
#   Transaction Date               Description      Category  Type  Amount  \
# 0       2025-01-20     PANCHOS MEXICAN GRILL  Food & Drink  Sale  -17.59
# 1       2025-01-20  BP#1027500MIRROR LAKE BP           Gas  Sale  -31.14
# 2       2025-01-20              LG - MIDTOWN  Food & Drink  Sale   -6.18
# 3       2025-01-20       MARATHON PETRO36889           Gas  Sale  -30.19
# 4       2025-01-18    PANERA BREAD #606169 O  Food & Drink  Sale  -10.52
#
#                 Merchant  Is_Recurring
# 0  panchos mexican grill         False
# 1       bpmirror lake bp         False
# 2             lg midtown         False
# 3         marathon petro         False
# 4         panera bread o         False

# %%
data[data['Is_Recurring']]
# Out:
#     Transaction Date             Description               Category  Type  \
# 6         2025-01-15           GOOGLE *Colab      Bills & Utilities  Sale
# 7         2025-01-10  OPENAI *CHATGPT SUBSCR               Shopping  Sale
# 8         2025-01-08         AMC 9640 ONLINE          Entertainment  Sale
# 11        2024-12-29             Spotify USA      Bills & Utilities  Sale
# 26        2024-12-15           GOOGLE *Colab               Shopping  Sale
# 29        2024-12-09  OPENAI *CHATGPT SUBSCR               Shopping  Sale
# 32        2024-12-08         AMC 9640 ONLINE          Entertainment  Sale
# 36        2024-11-29             Spotify USA      Bills & Utilities  Sale
# 43        2024-11-15           GOOGLE *Colab  Professional Services  Sale
# 45        2024-11-09  OPENAI *CHATGPT SUBSCR               Shopping  Sale
# 46        2024-11-08         AMC 9640 ONLINE          Entertainment  Sale
# 55        2024-10-29             Spotify USA      Bills & Utilities  Sale
# ...

# %%
data[data['Is_Recurring']]['Merchant'].unique()
# Out:
# array(['google colab', 'openai chatgpt subscr', 'amc online',
#        'spotify usa', 'peacock x premium'], dtype=object)
